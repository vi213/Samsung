# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('Expanded_Dataset.csv')

# Display the first few rows of your data
print(df.head())
# Out:
#    Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0  2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1  2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2  2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3  2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4  2019      Q1     Galaxy S21            No       45633  1.634244e+07
#
#    Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0              1.04                     57.36                      39.55
# 1              2.82                     85.80                      42.58
# 2             -0.03                     47.02                       3.78
# 3              0.84                     25.70                      23.41
# 4              2.36                     89.13                      44.43
#
#    Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# ...

# %%
pip install seaborn pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('Expanded_Dataset.csv')

# Display the first few rows of your dataset to confirm it's loaded correctly
print(df.head())
# Out:
#    Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0  2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1  2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2  2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3  2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4  2019      Q1     Galaxy S21            No       45633  1.634244e+07
#
#    Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0              1.04                     57.36                      39.55
# 1              2.82                     85.80                      42.58
# 2             -0.03                     47.02                       3.78
# 3              0.84                     25.70                      23.41
# 4              2.36                     89.13                      44.43
#
#    Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot with columns 'x_column' and 'y_column' from your dataset
sns.scatterplot(data=df, x='Regional 5G Coverage (%)', y='5G Subscribers (millions)')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('Expanded_Dataset.csv')

# Scatter plot with columns 'x_column' and 'y_column' from your dataset
sns.scatterplot(data=df, x='Regional 5G Coverage (%)', y='5G Subscribers (millions)')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(data=df, x="Regional 5G Coverage (%)", y="5G Subscribers (millions)")
plt.show()

# %%
sns.histplot(df['Regional 5G Coverage (%)'], kde=False)
# Out:
# <Axes: xlabel='Regional 5G Coverage (%)', ylabel='Count'>

# %%
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('Expanded_Dataset.csv')
sns.jointplot(x='Regional 5G Coverage (%)',y='5G Subscribers (millions)',data=df,kind='reg') # with regression line

# %%
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('Expanded_Dataset.csv')
sns.jointplot(x='Regional 5G Coverage (%)',y='5G Subscribers (millions)',data=df,kind='kde')

# %%
# BOX Plot

import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('Expanded_Dataset.csv')

sns.boxplot(x="Regional 5G Coverage (%)",y="Revenue ($)",data=df)
# Out:
# <Axes: xlabel='Regional 5G Coverage (%)', ylabel='Revenue ($)'>

# %%
# BOX Plot

import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('Expanded_Dataset.csv')
sns.barplot(x='Regional 5G Coverage (%)',y='Revenue ($)',data=df,palette='PuRd',ci=None,orient='h')
plt.legend()
plt.show()
# Out:
# C:\Users\vidya\AppData\Local\Temp\ipykernel_18824\593414131.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Regional 5G Coverage (%)',y='Revenue ($)',data=df,palette='PuRd',ci=None,orient='h')
# C:\Users\vidya\AppData\Local\Temp\ipykernel_18824\593414131.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Regional 5G Coverage (%)',y='Revenue ($)',data=df,palette='PuRd',ci=None,orient='h')
# C:\Users\vidya\AppData\Local\Temp\ipykernel_18824\593414131.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# BOX Plot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Load your dataset (adjust the file path)
df = pd.read_csv('code.csv')
sns.barplot(x='Regional 5G Coverage (%)',y='Revenue ($)',data=df,palette='PuRd',ci=None)
plt.legend()
plt.show()
# Out:
# C:\Users\vidya\AppData\Local\Temp\ipykernel_13240\3900517406.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Regional 5G Coverage (%)',y='Revenue ($)',data=df,palette='PuRd',ci=None)
# C:\Users\vidya\AppData\Local\Temp\ipykernel_13240\3900517406.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Regional 5G Coverage (%)',y='Revenue ($)',data=df,palette='PuRd',ci=None)
# C:\Users\vidya\AppData\Local\Temp\ipykernel_13240\3900517406.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#flights = flights.pivot("month","year","passengers")
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('code.csv')
flights_wide = df.pivot(index="Regional 5G Coverage (%)", columns="Revenue ($)", values="5G Subscribers (millions)")
print(flights_wide)

sns.heatmap(flights_wide,linewidth=0.5,cmap="YlGnBu")
# Out:
# Revenue ($)               25.70  44.77  47.02  51.21  52.94  56.50  57.36  \
# Regional 5G Coverage (%)
# 67.46                       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 77.25                       NaN    NaN  84.66    NaN    NaN    NaN    NaN
# 81.43                       NaN    NaN    NaN    NaN    NaN  85.88    NaN
# 105.27                    40.03    NaN    NaN    NaN    NaN    NaN    NaN
# 151.18                      NaN  66.51    NaN    NaN    NaN    NaN    NaN
# 179.15                      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 191.42                      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 206.17                      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 259.16                      NaN    NaN    NaN    NaN  77.55    NaN    NaN
# 284.33                      NaN    NaN    NaN  87.01    NaN    NaN    NaN
# 293.10                      NaN    NaN    NaN    NaN    NaN    NaN  55.87
#
# Revenue ($)               59.12  79.95  85.80  89.13
# ...
